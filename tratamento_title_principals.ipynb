# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('db/title.principals.tsv', sep='\t', na_values='\\N')

# %%
df.drop(columns=['characters'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98694690 entries, 0 to 98694689
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   tconst    str
#  1   ordering  int64
#  2   nconst    str
#  3   category  str
#  4   job       str
# dtypes: int64(1), str(4)
# memory usage: 6.2 GB

# %%
mask = (df['category'] == 'actor') | (df['category'] == 'actress')

df = df[mask]
df.drop(columns=['category', 'job'], inplace=True)

# %%
df.sort_values(by=['tconst', 'ordering'], inplace=True)

# %%
df.to_parquet('db/jobs.parquet')

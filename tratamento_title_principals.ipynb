# %%
import pandas as pd

# %%
df = pd.read_csv('db/title.principals.tsv', sep='\t', na_values='\\N')

# %%
df.drop(columns=['characters', 'ordering'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98694690 entries, 0 to 98694689
# Data columns (total 4 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   tconst    str
#  1   nconst    str
#  2   category  str
#  3   job       str
# dtypes: str(4)
# memory usage: 5.5 GB

# %%
mask = (df['category'] == 'actor') | (df['category'] == 'actress')

df = df[mask]
df.drop(columns=['category', 'job'], inplace=True)

# %%
df.to_parquet('db/actors.parquet')

# %%
import pandas as pd

# %%
df = pd.read_csv('db/name.basics.tsv', sep='\t', na_values='\\N')

# %%
df.drop(columns=['birthYear', 'deathYear', 'primaryProfession', 'knownForTitles'], inplace=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15206431 entries, 0 to 15206430
# Data columns (total 2 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   nconst       str
#  1   primaryName  str
# dtypes: str(2)
# memory usage: 568.0 MB

# %%
df.to_parquet('db/actors.parquet')
